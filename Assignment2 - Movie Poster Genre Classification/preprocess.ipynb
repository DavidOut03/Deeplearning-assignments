# %% [markdown]
# The data is right now saved as a mongo db objects. If we want to use it we must parse it to json.

# %%
import json
import re
    
def to_json(string: str):
    # Load the data as a string and parse it to json.

    # Find all JSON-like structures in the string
    matches = re.findall(r"(\{.*?\})", string, re.DOTALL)
    result = []

    for match in matches:
        try:
            # Remove the ObjectId(*)
            movie = re.sub(r'ObjectId\("([^"]*)"\)', r'"\1"', match)
            movie_obj = json.loads(movie)
            result.append(movie_obj)
        except json.JSONDecodeError as e:
            print(f"Error parsing JSON: {e}")
            continue
    
    return result

# %%
import os
import pandas as pd

folder = './data/Movie_Poster_Metadata'
filenames = os.listdir(folder)
movies = pd.DataFrame()

for filename in filenames:
    filepath = f"{folder}/{filename}"

    try:
        with open(file=filepath, mode='r', encoding='utf-16') as file:
            content = file.read() 
            data = to_json(content)
    except:
        with open(file=filepath, mode='r', encoding='utf-8') as file:
            content = file.read() 
            data = to_json(content)

    df = pd.DataFrame(data)
    movies = pd.concat([movies, pd.DataFrame(data)])
movies
# Out:
#                           _id Language   Box_office    Country    Rated  \
# 0    56fb860e71a0651b0c306f55  English  290,158,751        USA       PG
# 1    56fb860e71a0651b0c306f56  English  101,500,000        USA        R
# 2    56fb860e71a0651b0c306f57  English   83,400,000        USA       PG
# 3    56fb860e71a0651b0c306f58  English         None        USA       PG
# 4    56fb860e71a0651b0c306f59  English   69,800,000        USA        R
# ..                        ...      ...          ...        ...      ...
# 390  570780c771a0650b20736c69  English        1,711        USA      N/A
# 391  570780c771a0650b20736c6a  English        1,631  Australia  UNRATED
# 392  570780c771a0650b20736c6b  English        1,056        USA      N/A
# 393  570780c771a0650b20736c6c  English         None        USA      N/A
# 394  570780c771a0650b20736c6d  Spanish         None      Spain      N/A
#
#         imdbID                                             Awards  \
# 0    tt0080684     Won 1 Oscar. Another 15 wins & 18 nominations.
# 1    tt0081562                                      1 nomination.
# 2    tt0080339  Nominated for 1 Golden Globe. Another 2 wins &...
# 3    tt0080377                                             1 win.
# 4    tt0081375  Nominated for 3 Oscars. Another 1 win & 3 nomi...
# ..         ...                                                ...
# 390  tt2912776                                                N/A
# 391  tt2241750                            8 wins & 3 nominations.
# 392  tt4797082                                                N/A
# 393  tt5350540                                                N/A
# 394  tt4529904                                                N/A
#
#                                                 Poster  \
# 0    http://ia.media-imdb.com/images/M/MV5BMjE2MzQw...
# 1    http://ia.media-imdb.com/images/M/MV5BMTM4OTI3...
# 2    http://ia.media-imdb.com/images/M/MV5BNDU2MjE4...
# 3    http://ia.media-imdb.com/images/M/MV5BMTc5MTc5...
# 4    http://ia.media-imdb.com/images/M/MV5BMjIyNjkx...
# ..                                                 ...
# 390  http://ia.media-imdb.com/images/M/MV5BMTk4ODE4...
# 391  http://ia.media-imdb.com/images/M/MV5BMTcwNzc2...
# 392                                                N/A
# 393                                                N/A
# 394                                                N/A
#
#                                      Director     Released  \
# 0                              Irvin Kershner  20 Jun 1980
# 1                              Sidney Poitier  12 Dec 1980
# 2    Jim Abrahams, David Zucker, Jerry Zucker  02 Jul 1980
# 3                              Buddy Van Horn  17 Dec 1980
# 4                                Howard Zieff  10 Oct 1980
# ..                                        ...          ...
# 390                           John D. Hancock  27 Aug 2015
# 391                              Dean Francis  04 Mar 2015
# 392                              Muffie Meyer  30 Oct 2015
# 393                                       N/A  25 Aug 2015
# 394                           Pedro del Santo          N/A
#
#                                                 Writer imdbVotes  Runtime  \
# 0    Leigh Brackett (screenplay), Lawrence Kasdan (...   799,579  124 min
# 1                                   Bruce Jay Friedman    17,705  111 min
# 2    Jim Abrahams (written for the screen by), Davi...   154,994   88 min
# 3    Jeremy Joe Kronsberg (characters), Stanford Sh...    12,639  116 min
# 4           Nancy Meyers, Charles Shyer, Harvey Miller    17,591  109 min
# ..                                                 ...       ...      ...
# 390                   Dorothy Tristan, Dorothy Tristan         9  110 min
# 391  Stephen Davis, Dean Francis, Stephen Davis (play)       547   93 min
# 392                                                N/A       N/A   64 min
# 393                                                N/A       N/A    8 min
# 394                                  Helena Montesinos       N/A   89 min
#
#     Response imdbRating                                              Title  \
# 0       True        8.8     Star Wars: Episode V - The Empire Strikes Back
# 1       True        6.8                                         Stir Crazy
# 2       True        7.8                                          Airplane!
# 3       True        6.0                              Any Which Way You Can
# 4       True        6.1                                   Private Benjamin
# ..       ...        ...                                                ...
# 390     True        7.2                                  The Looking Glass
# 391     True        5.7                                              Drown
# 392     True        N/A                                      Making Rounds
# 393     True        N/A  Skin Trade: Behind the Action, Fighting You Ca...
# 394     True        N/A                                     Paranoid Girls
#
#                           Genre  \
# 0    Action, Adventure, Fantasy
# 1                 Comedy, Crime
# 2                        Comedy
# 3                Action, Comedy
# 4                   Comedy, War
# ..                          ...
# 390                Drama, Music
# 391                Drama, Sport
# 392                 Documentary
# 393          Documentary, Short
# 394                      Comedy
#
#                                                 Actors   Type Metascore
# 0    Mark Hamill, Harrison Ford, Carrie Fisher, Bil...  movie        79
# 1    Gene Wilder, Richard Pryor, Georg Stanford Bro...  movie        50
# 2    Kareem Abdul-Jabbar, Lloyd Bridges, Peter Grav...  movie       N/A
# 3    Clint Eastwood, Sondra Locke, Geoffrey Lewis, ...  movie       N/A
# 4    Goldie Hawn, Eileen Brennan, Armand Assante, R...  movie       N/A
# ..                                                 ...    ...       ...
# 390  Dorothy Tristan, Trish Basinger, Ed Ernstes, E...  movie       N/A
# 391  Matt Levett, Maya Stange, Jack Matthews, Harry...  movie       N/A
# 392                                                N/A  movie       N/A
# 393  Craig Baumgarten, Tony Jaa, Dolph Lundgren, Ro...  movie       N/A
# 394  Bárbara de Lema, Ángel de Miguel, Patricia Val...  movie       N/A
#
# [8873 rows x 20 columns]

# %% [markdown]
# Now we have all the metdata but not a link between the photos and the metadata. To create a connection between the metdata and the photos i created a dataframe for the photos and merged them.

# %%
from PIL import Image

photos = pd.DataFrame({
    'imdbID': [],
    'filename': [],
    'path': [],
    'extension': [],
    'width': [],
    'height': [],
    'file_size_kb': []
})

for folder in os.listdir('./data/Movie_Poster_Dataset'):

    for filename in os.listdir(f"./data/Movie_Poster_Dataset/{folder}"):
        full_path = f"./data/Movie_Poster_Dataset/{folder}/{filename}"

        img = Image.open(full_path)
        width, height = img.size
        
        # Get file size
        file_size = os.path.getsize(full_path) / 1024 


        photos = pd.concat([photos, pd.DataFrame({
            "imdbID": [filename.split('.')[0]], 
            "filename": [filename],
            "path": [f"Movie_Poster_Dataset/{folder}/{filename}"],
            "extension": [filename.split('.')[-1]],
            'width': [width],
            'height': [height],
            'file_size_kb': [file_size],
            'aspect_ratio': [(width / height
            )]
        })])  


dataset = pd.merge(left=movies, right=photos, left_on="imdbID", right_on="imdbID")
dataset = dataset.rename(columns=lambda x: x.lower())
dataset
# Out:
#                            _id language   box_office          country  \
# 0     56fb860e71a0651b0c306f55  English  290,158,751              USA
# 1     56fb860e71a0651b0c306f56  English  101,500,000              USA
# 2     56fb860e71a0651b0c306f57  English   83,400,000              USA
# 3     56fb860e71a0651b0c306f58  English         None              USA
# 4     56fb860e71a0651b0c306f59  English   69,800,000              USA
# ...                        ...      ...          ...              ...
# 8059  570780c771a0650b20736c65   French        2,033  France, Belgium
# 8060  570780c771a0650b20736c66  English         None              USA
# 8061  570780c771a0650b20736c67  English        1,903              USA
# 8062  570780c771a0650b20736c69  English        1,711              USA
# 8063  570780c771a0650b20736c6a  English        1,631        Australia
#
#         rated     imdbid                                             awards  \
# 0          PG  tt0080684     Won 1 Oscar. Another 15 wins & 18 nominations.
# 1           R  tt0081562                                      1 nomination.
# 2          PG  tt0080339  Nominated for 1 Golden Globe. Another 2 wins &...
# 3          PG  tt0080377                                             1 win.
# 4           R  tt0081375  Nominated for 3 Oscars. Another 1 win & 3 nomi...
# ...       ...        ...                                                ...
# 8059      N/A  tt4159182                                                N/A
# 8060      N/A  tt2265431                                                N/A
# 8061      N/A  tt3240784                                                N/A
# 8062      N/A  tt2912776                                                N/A
# 8063  UNRATED  tt2241750                            8 wins & 3 nominations.
#
#                                                  poster  \
# 0     http://ia.media-imdb.com/images/M/MV5BMjE2MzQw...
# 1     http://ia.media-imdb.com/images/M/MV5BMTM4OTI3...
# 2     http://ia.media-imdb.com/images/M/MV5BNDU2MjE4...
# 3     http://ia.media-imdb.com/images/M/MV5BMTc5MTc5...
# 4     http://ia.media-imdb.com/images/M/MV5BMjIyNjkx...
# ...                                                 ...
# 8059  http://ia.media-imdb.com/images/M/MV5BMTY1Njc5...
# 8060  http://ia.media-imdb.com/images/M/MV5BMTgzODUx...
# 8061  http://ia.media-imdb.com/images/M/MV5BMTY4NjUy...
# 8062  http://ia.media-imdb.com/images/M/MV5BMTk4ODE4...
# 8063  http://ia.media-imdb.com/images/M/MV5BMTcwNzc2...
#
#                                       director     released  ...  \
# 0                               Irvin Kershner  20 Jun 1980  ...
# 1                               Sidney Poitier  12 Dec 1980  ...
# 2     Jim Abrahams, David Zucker, Jerry Zucker  02 Jul 1980  ...
# 3                               Buddy Van Horn  17 Dec 1980  ...
# 4                                 Howard Zieff  10 Oct 1980  ...
# ...                                        ...          ...  ...
# 8059                                Joann Sfar  18 Dec 2015  ...
# 8060                            Jaime Zevallos  07 Jul 2015  ...
# 8061         David T. Friendly, Mick Partridge  07 Aug 2015  ...
# 8062                           John D. Hancock  27 Aug 2015  ...
# 8063                              Dean Francis  04 Mar 2015  ...
#
#                                                  actors   type metascore  \
# 0     Mark Hamill, Harrison Ford, Carrie Fisher, Bil...  movie        79
# 1     Gene Wilder, Richard Pryor, Georg Stanford Bro...  movie        50
# 2     Kareem Abdul-Jabbar, Lloyd Bridges, Peter Grav...  movie       N/A
# 3     Clint Eastwood, Sondra Locke, Geoffrey Lewis, ...  movie       N/A
# 4     Goldie Hawn, Eileen Brennan, Armand Assante, R...  movie       N/A
# ...                                                 ...    ...       ...
# 8059  Freya Mavor, Benjamin Biolay, Elio Germano, St...  movie       N/A
# 8060  Angela Sarafyan, Jaime Zevallos, Sean Nateghi,...  movie       N/A
# 8061                                                N/A  movie        50
# 8062  Dorothy Tristan, Trish Basinger, Ed Ernstes, E...  movie       N/A
# 8063  Matt Levett, Maya Stange, Jack Matthews, Harry...  movie       N/A
#
#            filename                                     path extension  width  \
# 0     tt0080684.jpg  Movie_Poster_Dataset/1980/tt0080684.jpg       jpg  300.0
# 1     tt0081562.jpg  Movie_Poster_Dataset/1980/tt0081562.jpg       jpg  300.0
# 2     tt0080339.jpg  Movie_Poster_Dataset/1980/tt0080339.jpg       jpg  300.0
# 3     tt0080377.jpg  Movie_Poster_Dataset/1980/tt0080377.jpg       jpg  300.0
# 4     tt0081375.jpg  Movie_Poster_Dataset/1980/tt0081375.jpg       jpg  300.0
# ...             ...                                      ...       ...    ...
# 8059  tt4159182.jpg  Movie_Poster_Dataset/2015/tt4159182.jpg       jpg  300.0
# 8060  tt2265431.jpg  Movie_Poster_Dataset/2015/tt2265431.jpg       jpg  300.0
# 8061  tt3240784.jpg  Movie_Poster_Dataset/2015/tt3240784.jpg       jpg  300.0
# 8062  tt2912776.jpg  Movie_Poster_Dataset/2015/tt2912776.jpg       jpg  300.0
# 8063  tt2241750.jpg  Movie_Poster_Dataset/2015/tt2241750.jpg       jpg  300.0
#
#      height file_size_kb aspect_ratio
# 0     444.0    32.535156     0.675676
# 1     438.0    42.684570     0.684932
# 2     444.0    30.916016     0.675676
# 3     432.0    42.120117     0.694444
# 4     444.0    30.539062     0.675676
# ...     ...          ...          ...
# 8059  443.0    30.335938     0.677201
# 8060  419.0    39.723633     0.715990
# 8061  442.0    41.201172     0.678733
# 8062  444.0    21.246094     0.675676
# 8063  438.0    34.910156     0.684932
#
# [8064 rows x 27 columns]

# %%
dataset
# Out:
#                            _id language   box_office          country  \
# 0     56fb860e71a0651b0c306f55  English  290,158,751              USA
# 1     56fb860e71a0651b0c306f56  English  101,500,000              USA
# 2     56fb860e71a0651b0c306f57  English   83,400,000              USA
# 3     56fb860e71a0651b0c306f58  English         None              USA
# 4     56fb860e71a0651b0c306f59  English   69,800,000              USA
# ...                        ...      ...          ...              ...
# 8059  570780c771a0650b20736c65   French        2,033  France, Belgium
# 8060  570780c771a0650b20736c66  English         None              USA
# 8061  570780c771a0650b20736c67  English        1,903              USA
# 8062  570780c771a0650b20736c69  English        1,711              USA
# 8063  570780c771a0650b20736c6a  English        1,631        Australia
#
#         rated     imdbid                                             awards  \
# 0          PG  tt0080684     Won 1 Oscar. Another 15 wins & 18 nominations.
# 1           R  tt0081562                                      1 nomination.
# 2          PG  tt0080339  Nominated for 1 Golden Globe. Another 2 wins &...
# 3          PG  tt0080377                                             1 win.
# 4           R  tt0081375  Nominated for 3 Oscars. Another 1 win & 3 nomi...
# ...       ...        ...                                                ...
# 8059      N/A  tt4159182                                                N/A
# 8060      N/A  tt2265431                                                N/A
# 8061      N/A  tt3240784                                                N/A
# 8062      N/A  tt2912776                                                N/A
# 8063  UNRATED  tt2241750                            8 wins & 3 nominations.
#
#                                                  poster  \
# 0     http://ia.media-imdb.com/images/M/MV5BMjE2MzQw...
# 1     http://ia.media-imdb.com/images/M/MV5BMTM4OTI3...
# 2     http://ia.media-imdb.com/images/M/MV5BNDU2MjE4...
# 3     http://ia.media-imdb.com/images/M/MV5BMTc5MTc5...
# 4     http://ia.media-imdb.com/images/M/MV5BMjIyNjkx...
# ...                                                 ...
# 8059  http://ia.media-imdb.com/images/M/MV5BMTY1Njc5...
# 8060  http://ia.media-imdb.com/images/M/MV5BMTgzODUx...
# 8061  http://ia.media-imdb.com/images/M/MV5BMTY4NjUy...
# 8062  http://ia.media-imdb.com/images/M/MV5BMTk4ODE4...
# 8063  http://ia.media-imdb.com/images/M/MV5BMTcwNzc2...
#
#                                       director     released  ...  \
# 0                               Irvin Kershner  20 Jun 1980  ...
# 1                               Sidney Poitier  12 Dec 1980  ...
# 2     Jim Abrahams, David Zucker, Jerry Zucker  02 Jul 1980  ...
# 3                               Buddy Van Horn  17 Dec 1980  ...
# 4                                 Howard Zieff  10 Oct 1980  ...
# ...                                        ...          ...  ...
# 8059                                Joann Sfar  18 Dec 2015  ...
# 8060                            Jaime Zevallos  07 Jul 2015  ...
# 8061         David T. Friendly, Mick Partridge  07 Aug 2015  ...
# 8062                           John D. Hancock  27 Aug 2015  ...
# 8063                              Dean Francis  04 Mar 2015  ...
#
#                                                  actors   type metascore  \
# 0     Mark Hamill, Harrison Ford, Carrie Fisher, Bil...  movie        79
# 1     Gene Wilder, Richard Pryor, Georg Stanford Bro...  movie        50
# 2     Kareem Abdul-Jabbar, Lloyd Bridges, Peter Grav...  movie       N/A
# 3     Clint Eastwood, Sondra Locke, Geoffrey Lewis, ...  movie       N/A
# 4     Goldie Hawn, Eileen Brennan, Armand Assante, R...  movie       N/A
# ...                                                 ...    ...       ...
# 8059  Freya Mavor, Benjamin Biolay, Elio Germano, St...  movie       N/A
# 8060  Angela Sarafyan, Jaime Zevallos, Sean Nateghi,...  movie       N/A
# 8061                                                N/A  movie        50
# 8062  Dorothy Tristan, Trish Basinger, Ed Ernstes, E...  movie       N/A
# 8063  Matt Levett, Maya Stange, Jack Matthews, Harry...  movie       N/A
#
#            filename                                     path extension  width  \
# 0     tt0080684.jpg  Movie_Poster_Dataset/1980/tt0080684.jpg       jpg  300.0
# 1     tt0081562.jpg  Movie_Poster_Dataset/1980/tt0081562.jpg       jpg  300.0
# 2     tt0080339.jpg  Movie_Poster_Dataset/1980/tt0080339.jpg       jpg  300.0
# 3     tt0080377.jpg  Movie_Poster_Dataset/1980/tt0080377.jpg       jpg  300.0
# 4     tt0081375.jpg  Movie_Poster_Dataset/1980/tt0081375.jpg       jpg  300.0
# ...             ...                                      ...       ...    ...
# 8059  tt4159182.jpg  Movie_Poster_Dataset/2015/tt4159182.jpg       jpg  300.0
# 8060  tt2265431.jpg  Movie_Poster_Dataset/2015/tt2265431.jpg       jpg  300.0
# 8061  tt3240784.jpg  Movie_Poster_Dataset/2015/tt3240784.jpg       jpg  300.0
# 8062  tt2912776.jpg  Movie_Poster_Dataset/2015/tt2912776.jpg       jpg  300.0
# 8063  tt2241750.jpg  Movie_Poster_Dataset/2015/tt2241750.jpg       jpg  300.0
#
#      height file_size_kb aspect_ratio
# 0     444.0    32.535156     0.675676
# 1     438.0    42.684570     0.684932
# 2     444.0    30.916016     0.675676
# 3     432.0    42.120117     0.694444
# 4     444.0    30.539062     0.675676
# ...     ...          ...          ...
# 8059  443.0    30.335938     0.677201
# 8060  419.0    39.723633     0.715990
# 8061  442.0    41.201172     0.678733
# 8062  444.0    21.246094     0.675676
# 8063  438.0    34.910156     0.684932
#
# [8064 rows x 27 columns]

# %% [markdown]
# Year 1992 has metadata but no images so thats why the dataframe is different in size.

# %% [markdown]
# The dates are also not processable right now so im going to split the into different columns

# %%
for index, row in dataset.iterrows():
    date = row['released']

    if not date or date == 'N/A':
        continue

    
    datestring = date.split(' ')
    if len(datestring) == 3:
        day, month, year = datestring
        dataset.at[index, 'day'] = int(day.strip())
        dataset.at[index, 'month'] = month.strip()
        dataset.at[index, 'year'] = int(year.strip())

dataset
# Out:
#                            _id language   box_office          country  \
# 0     56fb860e71a0651b0c306f55  English  290,158,751              USA
# 1     56fb860e71a0651b0c306f56  English  101,500,000              USA
# 2     56fb860e71a0651b0c306f57  English   83,400,000              USA
# 3     56fb860e71a0651b0c306f58  English         None              USA
# 4     56fb860e71a0651b0c306f59  English   69,800,000              USA
# ...                        ...      ...          ...              ...
# 8059  570780c771a0650b20736c65   French        2,033  France, Belgium
# 8060  570780c771a0650b20736c66  English         None              USA
# 8061  570780c771a0650b20736c67  English        1,903              USA
# 8062  570780c771a0650b20736c69  English        1,711              USA
# 8063  570780c771a0650b20736c6a  English        1,631        Australia
#
#         rated     imdbid                                             awards  \
# 0          PG  tt0080684     Won 1 Oscar. Another 15 wins & 18 nominations.
# 1           R  tt0081562                                      1 nomination.
# 2          PG  tt0080339  Nominated for 1 Golden Globe. Another 2 wins &...
# 3          PG  tt0080377                                             1 win.
# 4           R  tt0081375  Nominated for 3 Oscars. Another 1 win & 3 nomi...
# ...       ...        ...                                                ...
# 8059      N/A  tt4159182                                                N/A
# 8060      N/A  tt2265431                                                N/A
# 8061      N/A  tt3240784                                                N/A
# 8062      N/A  tt2912776                                                N/A
# 8063  UNRATED  tt2241750                            8 wins & 3 nominations.
#
#                                                  poster  \
# 0     http://ia.media-imdb.com/images/M/MV5BMjE2MzQw...
# 1     http://ia.media-imdb.com/images/M/MV5BMTM4OTI3...
# 2     http://ia.media-imdb.com/images/M/MV5BNDU2MjE4...
# 3     http://ia.media-imdb.com/images/M/MV5BMTc5MTc5...
# 4     http://ia.media-imdb.com/images/M/MV5BMjIyNjkx...
# ...                                                 ...
# 8059  http://ia.media-imdb.com/images/M/MV5BMTY1Njc5...
# 8060  http://ia.media-imdb.com/images/M/MV5BMTgzODUx...
# 8061  http://ia.media-imdb.com/images/M/MV5BMTY4NjUy...
# 8062  http://ia.media-imdb.com/images/M/MV5BMTk4ODE4...
# 8063  http://ia.media-imdb.com/images/M/MV5BMTcwNzc2...
#
#                                       director     released  ...  \
# 0                               Irvin Kershner  20 Jun 1980  ...
# 1                               Sidney Poitier  12 Dec 1980  ...
# 2     Jim Abrahams, David Zucker, Jerry Zucker  02 Jul 1980  ...
# 3                               Buddy Van Horn  17 Dec 1980  ...
# 4                                 Howard Zieff  10 Oct 1980  ...
# ...                                        ...          ...  ...
# 8059                                Joann Sfar  18 Dec 2015  ...
# 8060                            Jaime Zevallos  07 Jul 2015  ...
# 8061         David T. Friendly, Mick Partridge  07 Aug 2015  ...
# 8062                           John D. Hancock  27 Aug 2015  ...
# 8063                              Dean Francis  04 Mar 2015  ...
#
#            filename                                     path extension  width  \
# 0     tt0080684.jpg  Movie_Poster_Dataset/1980/tt0080684.jpg       jpg  300.0
# 1     tt0081562.jpg  Movie_Poster_Dataset/1980/tt0081562.jpg       jpg  300.0
# 2     tt0080339.jpg  Movie_Poster_Dataset/1980/tt0080339.jpg       jpg  300.0
# 3     tt0080377.jpg  Movie_Poster_Dataset/1980/tt0080377.jpg       jpg  300.0
# 4     tt0081375.jpg  Movie_Poster_Dataset/1980/tt0081375.jpg       jpg  300.0
# ...             ...                                      ...       ...    ...
# 8059  tt4159182.jpg  Movie_Poster_Dataset/2015/tt4159182.jpg       jpg  300.0
# 8060  tt2265431.jpg  Movie_Poster_Dataset/2015/tt2265431.jpg       jpg  300.0
# 8061  tt3240784.jpg  Movie_Poster_Dataset/2015/tt3240784.jpg       jpg  300.0
# 8062  tt2912776.jpg  Movie_Poster_Dataset/2015/tt2912776.jpg       jpg  300.0
# 8063  tt2241750.jpg  Movie_Poster_Dataset/2015/tt2241750.jpg       jpg  300.0
#
#      height file_size_kb aspect_ratio   day month    year
# 0     444.0    32.535156     0.675676  20.0   Jun  1980.0
# 1     438.0    42.684570     0.684932  12.0   Dec  1980.0
# 2     444.0    30.916016     0.675676   2.0   Jul  1980.0
# 3     432.0    42.120117     0.694444  17.0   Dec  1980.0
# 4     444.0    30.539062     0.675676  10.0   Oct  1980.0
# ...     ...          ...          ...   ...   ...     ...
# 8059  443.0    30.335938     0.677201  18.0   Dec  2015.0
# 8060  419.0    39.723633     0.715990   7.0   Jul  2015.0
# 8061  442.0    41.201172     0.678733   7.0   Aug  2015.0
# 8062  444.0    21.246094     0.675676  27.0   Aug  2015.0
# 8063  438.0    34.910156     0.684932   4.0   Mar  2015.0
#
# [8064 rows x 30 columns]

# %%
print(dataset.columns.tolist())
# Out:
# ['_id', 'language', 'box_office', 'country', 'rated', 'imdbid', 'awards', 'poster', 'director', 'released', 'writer', 'imdbvotes', 'runtime', 'response', 'imdbrating', 'title', 'genre', 'actors', 'type', 'metascore', 'filename', 'path', 'extension', 'width', 'height', 'file_size_kb', 'aspect_ratio', 'day', 'month', 'year']

# %% [markdown]
# I wont need all of these columsn for training so i dropped the columns i do not need.

# %%
dataset.drop(['_id', 'country', 'box_office', 'language', 'rated', 'awards', 
            'poster', 'director', 'released', 'actors', 'metascore', 'writer', 
            'imdbvotes', 'response', 'imdbrating', 'title', 'type', 'runtime', 'day', 'month'], 
            axis=1, inplace=True)

dataset
# Out:
#          imdbid                       genre       filename  \
# 0     tt0080684  Action, Adventure, Fantasy  tt0080684.jpg
# 1     tt0081562               Comedy, Crime  tt0081562.jpg
# 2     tt0080339                      Comedy  tt0080339.jpg
# 3     tt0080377              Action, Comedy  tt0080377.jpg
# 4     tt0081375                 Comedy, War  tt0081375.jpg
# ...         ...                         ...            ...
# 8059  tt4159182                    Thriller  tt4159182.jpg
# 8060  tt2265431      Comedy, Drama, Romance  tt2265431.jpg
# 8061  tt3240784                 Documentary  tt3240784.jpg
# 8062  tt2912776                Drama, Music  tt2912776.jpg
# 8063  tt2241750                Drama, Sport  tt2241750.jpg
#
#                                          path extension  width  height  \
# 0     Movie_Poster_Dataset/1980/tt0080684.jpg       jpg  300.0   444.0
# 1     Movie_Poster_Dataset/1980/tt0081562.jpg       jpg  300.0   438.0
# 2     Movie_Poster_Dataset/1980/tt0080339.jpg       jpg  300.0   444.0
# 3     Movie_Poster_Dataset/1980/tt0080377.jpg       jpg  300.0   432.0
# 4     Movie_Poster_Dataset/1980/tt0081375.jpg       jpg  300.0   444.0
# ...                                       ...       ...    ...     ...
# 8059  Movie_Poster_Dataset/2015/tt4159182.jpg       jpg  300.0   443.0
# 8060  Movie_Poster_Dataset/2015/tt2265431.jpg       jpg  300.0   419.0
# 8061  Movie_Poster_Dataset/2015/tt3240784.jpg       jpg  300.0   442.0
# 8062  Movie_Poster_Dataset/2015/tt2912776.jpg       jpg  300.0   444.0
# 8063  Movie_Poster_Dataset/2015/tt2241750.jpg       jpg  300.0   438.0
#
#       file_size_kb  aspect_ratio    year
# 0        32.535156      0.675676  1980.0
# 1        42.684570      0.684932  1980.0
# 2        30.916016      0.675676  1980.0
# 3        42.120117      0.694444  1980.0
# 4        30.539062      0.675676  1980.0
# ...            ...           ...     ...
# 8059     30.335938      0.677201  2015.0
# 8060     39.723633      0.715990  2015.0
# 8061     41.201172      0.678733  2015.0
# 8062     21.246094      0.675676  2015.0
# 8063     34.910156      0.684932  2015.0
#
# [8064 rows x 10 columns]

# %%
# Save to Excel
dataset.to_excel('./data/data.xlsx', index=False, engine='openpyxl')
